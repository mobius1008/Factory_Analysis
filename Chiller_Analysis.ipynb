# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# path = 'F132FAHU01/'
# target = "F13 2F "
target_factory = 'F1,2'
floor = ''
# target_string = "冰水主機1"
Name_string_1 = '冰水主機1'
Item_string_1 = 'Chiller01'
Name_string_2 = '冰水主機2'
Item_string_2 = 'Chiller02'
Name_string_3 = '冰水主機3'
Item_string_3 = 'Chiller03'
Name_string_4 = '冰水主機4'
Item_string_4 = 'Chiller04'
Name_string_7 = '冰水主機7'
Item_string_7 = 'Chiller07'
# folder_path = 'F0102Chiller07/'
# file_name = path +'ST.csv'
# df_ST = pd.read_csv(file_name)
# # df_ST = pd.read_csv('F132FAHU05/ST.csv')

# %%
debug_print = 1
debug_save_img = 1
img_num = 0

# %%
# target_string_temp = target + target_string
# target_string_temp = target_factory+''+floor+''+target_string
check_name_string_1 = target_factory+Name_string_1
plot_title_1 = target_factory+' '+Item_string_1
print("check_name_string =",check_name_string_1)
print("plot_title =",plot_title_1)
# Out:
# check_name_string = F1,2冰水主機1
# plot_title = F1,2 Chiller01

# %%
check_name_string_2 = target_factory+Name_string_2
plot_title_2 = target_factory+' '+Item_string_2

check_name_string_3 = target_factory+Name_string_3
plot_title_3 = target_factory+' '+Item_string_3

check_name_string_4 = target_factory+Name_string_4
plot_title_4 = target_factory+' '+Item_string_4

check_name_string_7 = target_factory+Name_string_7
plot_title_7 = target_factory+' '+Item_string_7

# %%
file_name ='RowData.csv'
df_temp = pd.read_csv(file_name)

# %%
print(df_temp.head())
print(df_temp.tail())
print(df_temp.shape)
# Out:
#      Name         Type    Value  Unit        Date   Time
# 0  F1回水溫度  Temperature  11.5219   NaN  2019/06/18  21:00
# 1  F1回水溫度  Temperature  11.5354   NaN  2019/06/18  21:05
# 2  F1回水溫度  Temperature  11.5472   NaN  2019/06/18  21:10
# 3  F1回水溫度  Temperature  11.6179   NaN  2019/06/18  21:15
# 4  F1回水溫度  Temperature  11.6044   NaN  2019/06/18  21:20
#            Name             Type  Value  Unit        Date   Time
# 3162  F1,2冰水主機7  IceWaterControl    6.0   NaN  2019/06/19  14:45
# 3163  F1,2冰水主機7  IceWaterControl    6.0   NaN  2019/06/19  14:50
# 3164  F1,2冰水主機7  IceWaterControl    6.0   NaN  2019/06/19  14:55
# 3165  F1,2冰水主機7  IceWaterControl    6.0   NaN  2019/06/19  15:00
# 3166  F1,2冰水主機7  IceWaterControl    6.0   NaN  2019/06/19  15:05
# (3167, 6)

# %%
this_target  = "Return_Temperature"
temp = df_temp[(df_temp['Name']== "F1回水溫度")].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_Return_Temperature =this_target
temp[temp_string_Return_Temperature] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_Return_Temperature = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_Return_Temperature.head())
print(temp_df_Return_Temperature.shape)
# Out:
#      Name         Type    Value  Unit        Date   Time
# 0  F1回水溫度  Temperature  11.5219   NaN  2019/06/18  21:00
# 1  F1回水溫度  Temperature  11.5354   NaN  2019/06/18  21:05
# 2  F1回水溫度  Temperature  11.5472   NaN  2019/06/18  21:10
# 3  F1回水溫度  Temperature  11.6179   NaN  2019/06/18  21:15
# 4  F1回水溫度  Temperature  11.6044   NaN  2019/06/18  21:20
# (197, 6)
#      Name         Type    Value  Unit        Date   Time           Date_Time  \
# 0  F1回水溫度  Temperature  11.5219   NaN  2019/06/18  21:00 2019-06-18 21:00:00
# 1  F1回水溫度  Temperature  11.5354   NaN  2019/06/18  21:05 2019-06-18 21:05:00
# 2  F1回水溫度  Temperature  11.5472   NaN  2019/06/18  21:10 2019-06-18 21:10:00
# 3  F1回水溫度  Temperature  11.6179   NaN  2019/06/18  21:15 2019-06-18 21:15:00
# 4  F1回水溫度  Temperature  11.6044   NaN  2019/06/18  21:20 2019-06-18 21:20:00
#
#    Return_Temperature
# 0             11.5219
# 1             11.5354
# 2             11.5472
# 3             11.6179
# 4             11.6044
# (197, 8)
# ...

# %%
this_target  = "ChillerOnOff"
temp = df_temp[(df_temp['Name']== check_name_string_1)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_ChillerOnOff = Item_string_1+"_"+this_target
temp[temp_string_ChillerOnOff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_ChillerOnOff = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_ChillerOnOff.head())
    print(temp_df_ChillerOnOff.shape)
temp_df_ChillerOnOff = temp_df_ChillerOnOff.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_ChillerOnOff.head())
print(temp_df_ChillerOnOff.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller01_ChillerOnOff
# 0 2019-06-18 21:00:00                     0.0
# 1 2019-06-18 21:05:00                     0.0
# 2 2019-06-18 21:10:00                     0.0
# 3 2019-06-18 21:15:00                     0.0
# ...

# %%
this_target  = "IceWaterOutletTemperature"
temp = df_temp[(df_temp['Name']== check_name_string_1)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterOutletTemperature = Item_string_1+"_"+this_target
temp[temp_string_IceWaterOutletTemperature] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterOutletTemperature = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterOutletTemperature.head())
    print(temp_df_IceWaterOutletTemperature.shape)
temp_df_IceWaterOutletTemperature = temp_df_IceWaterOutletTemperature.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterOutletTemperature.head())
print(temp_df_IceWaterOutletTemperature.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller01_IceWaterOutletTemperature
# 0 2019-06-18 21:00:00                                  0.0
# 1 2019-06-18 21:05:00                                  0.0
# 2 2019-06-18 21:10:00                                  0.0
# ...

# %%
this_target  = "IceWaterControl"
temp = df_temp[(df_temp['Name']== check_name_string_1)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterControl = Item_string_1+"_"+this_target
temp[temp_string_IceWaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterControl = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterControl.head())
    print(temp_df_IceWaterControl.shape)
temp_df_IceWaterControl = temp_df_IceWaterControl.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterControl.head())
print(temp_df_IceWaterControl.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機1  ChillerOnOff    0.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller01_IceWaterControl
# 0 2019-06-18 21:00:00                        0.0
# 1 2019-06-18 21:05:00                        0.0
# 2 2019-06-18 21:10:00                        0.0
# ...

# %%
temp = temp_df_Return_Temperature
temp = pd.merge(temp,temp_df_ChillerOnOff)
temp = pd.merge(temp,temp_df_IceWaterOutletTemperature)
temp = pd.merge(temp,temp_df_IceWaterControl)

# %%
print(temp.head())
print(temp.shape)
# Out:
#             Date_Time  Return_Temperature  Chiller01_ChillerOnOff  \
# 0 2019-06-18 21:00:00             11.5219                     0.0
# 1 2019-06-18 21:05:00             11.5354                     0.0
# 2 2019-06-18 21:10:00             11.5472                     0.0
# 3 2019-06-18 21:15:00             11.6179                     0.0
# 4 2019-06-18 21:20:00             11.6044                     0.0
#
#    Chiller01_IceWaterOutletTemperature  Chiller01_IceWaterControl
# 0                                12.44                        7.0
# 1                                12.45                        7.0
# 2                                12.41                        7.0
# 3                                12.33                        7.0
# 4                                12.33                        7.0
# (197, 5)

# %%
x = temp['Date_Time'] 
y = temp[temp_string_Return_Temperature]
y1= temp[temp_string_ChillerOnOff]
y2= temp[temp_string_IceWaterOutletTemperature]
y3= temp[temp_string_IceWaterControl]

fig = plt.figure(figsize=(20,12))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title_1)
a1.plot(x,y,label=temp_string_Return_Temperature)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_ChillerOnOff)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_IceWaterOutletTemperature)
a1.legend()

a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_IceWaterControl )
a1.legend()


if(debug_save_img):
    img_num = img_num+1
#     temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    temp = target_factory+'_'+Item_string_1+'_'+str(img_num)
    fig.savefig(fname = temp)

# %%
this_target  = "ChillerOnOff"
temp = df_temp[(df_temp['Name']== check_name_string_2)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_ChillerOnOff = Item_string_2+"_"+this_target
temp[temp_string_ChillerOnOff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_ChillerOnOff = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_ChillerOnOff.head())
    print(temp_df_ChillerOnOff.shape)
temp_df_ChillerOnOff = temp_df_ChillerOnOff.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_ChillerOnOff.head())
print(temp_df_ChillerOnOff.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller02_ChillerOnOff
# 0 2019-06-18 21:00:00                     1.0
# 1 2019-06-18 21:05:00                     1.0
# 2 2019-06-18 21:10:00                     1.0
# 3 2019-06-18 21:15:00                     1.0
# ...

# %%
this_target  = "IceWaterOutletTemperature"
temp = df_temp[(df_temp['Name']== check_name_string_2)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterOutletTemperature = Item_string_2+"_"+this_target
temp[temp_string_IceWaterOutletTemperature] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterOutletTemperature = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterOutletTemperature.head())
    print(temp_df_IceWaterOutletTemperature.shape)
temp_df_IceWaterOutletTemperature = temp_df_IceWaterOutletTemperature.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterOutletTemperature.head())
print(temp_df_IceWaterOutletTemperature.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller02_IceWaterOutletTemperature
# 0 2019-06-18 21:00:00                                  1.0
# 1 2019-06-18 21:05:00                                  1.0
# 2 2019-06-18 21:10:00                                  1.0
# ...

# %%
this_target  = "IceWaterControl"
temp = df_temp[(df_temp['Name']== check_name_string_2)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterControl = Item_string_2+"_"+this_target
temp[temp_string_IceWaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterControl = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterControl.head())
    print(temp_df_IceWaterControl.shape)
temp_df_IceWaterControl = temp_df_IceWaterControl.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterControl.head())
print(temp_df_IceWaterControl.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機2  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller02_IceWaterControl
# 0 2019-06-18 21:00:00                        1.0
# 1 2019-06-18 21:05:00                        1.0
# 2 2019-06-18 21:10:00                        1.0
# ...

# %%
temp = temp_df_Return_Temperature
temp = pd.merge(temp,temp_df_ChillerOnOff)
temp = pd.merge(temp,temp_df_IceWaterOutletTemperature)
temp = pd.merge(temp,temp_df_IceWaterControl)

# %%
x = temp['Date_Time'] 
y = temp[temp_string_Return_Temperature]
y1= temp[temp_string_ChillerOnOff]
y2= temp[temp_string_IceWaterOutletTemperature]
y3= temp[temp_string_IceWaterControl]

fig = plt.figure(figsize=(20,12))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title_2)
a1.plot(x,y,label=temp_string_Return_Temperature)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_ChillerOnOff)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_IceWaterOutletTemperature)
a1.legend()

a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_IceWaterControl )
a1.legend()


if(debug_save_img):
    img_num = img_num+1
#     temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    temp = target_factory+'_'+Item_string_2+'_'+str(img_num)
    fig.savefig(fname = temp)

# %%
this_target  = "ChillerOnOff"
temp = df_temp[(df_temp['Name']== check_name_string_3)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_ChillerOnOff = Item_string_3+"_"+this_target
temp[temp_string_ChillerOnOff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_ChillerOnOff = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_ChillerOnOff.head())
    print(temp_df_ChillerOnOff.shape)
temp_df_ChillerOnOff = temp_df_ChillerOnOff.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_ChillerOnOff.head())
print(temp_df_ChillerOnOff.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller03_ChillerOnOff
# 0 2019-06-18 21:00:00                     0.0
# 1 2019-06-18 21:05:00                     0.0
# 2 2019-06-18 21:10:00                     0.0
# 3 2019-06-18 21:15:00                     0.0
# ...

# %%
this_target  = "IceWaterOutletTemperature"
temp = df_temp[(df_temp['Name']== check_name_string_3)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterOutletTemperature = Item_string_3+"_"+this_target
temp[temp_string_IceWaterOutletTemperature] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterOutletTemperature = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterOutletTemperature.head())
    print(temp_df_IceWaterOutletTemperature.shape)
temp_df_IceWaterOutletTemperature = temp_df_IceWaterOutletTemperature.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterOutletTemperature.head())
print(temp_df_IceWaterOutletTemperature.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller03_IceWaterOutletTemperature
# 0 2019-06-18 21:00:00                                  0.0
# 1 2019-06-18 21:05:00                                  0.0
# 2 2019-06-18 21:10:00                                  0.0
# ...

# %%
this_target  = "IceWaterControl"
temp = df_temp[(df_temp['Name']== check_name_string_3)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterControl = Item_string_3+"_"+this_target
temp[temp_string_IceWaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterControl = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterControl.head())
    print(temp_df_IceWaterControl.shape)
temp_df_IceWaterControl = temp_df_IceWaterControl.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterControl.head())
print(temp_df_IceWaterControl.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機3  ChillerOnOff    0.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller03_IceWaterControl
# 0 2019-06-18 21:00:00                        0.0
# 1 2019-06-18 21:05:00                        0.0
# 2 2019-06-18 21:10:00                        0.0
# ...

# %%
temp = temp_df_Return_Temperature
temp = pd.merge(temp,temp_df_ChillerOnOff)
temp = pd.merge(temp,temp_df_IceWaterOutletTemperature)
temp = pd.merge(temp,temp_df_IceWaterControl)

# %%
x = temp['Date_Time'] 
y = temp[temp_string_Return_Temperature]
y1= temp[temp_string_ChillerOnOff]
y2= temp[temp_string_IceWaterOutletTemperature]
y3= temp[temp_string_IceWaterControl]

fig = plt.figure(figsize=(20,12))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title_3)
a1.plot(x,y,label=temp_string_Return_Temperature)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_ChillerOnOff)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_IceWaterOutletTemperature)
a1.legend()

a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_IceWaterControl )
a1.legend()


if(debug_save_img):
    img_num = img_num+1
#     temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    temp = target_factory+'_'+Item_string_3+'_'+str(img_num)
    fig.savefig(fname = temp)

# %%
this_target  = "ChillerOnOff"
temp = df_temp[(df_temp['Name']== check_name_string_4)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_ChillerOnOff = Item_string_4+"_"+this_target
temp[temp_string_ChillerOnOff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_ChillerOnOff = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_ChillerOnOff.head())
    print(temp_df_ChillerOnOff.shape)
temp_df_ChillerOnOff = temp_df_ChillerOnOff.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_ChillerOnOff.head())
print(temp_df_ChillerOnOff.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller04_ChillerOnOff
# 0 2019-06-18 21:00:00                     1.0
# 1 2019-06-18 21:05:00                     1.0
# 2 2019-06-18 21:10:00                     1.0
# 3 2019-06-18 21:15:00                     1.0
# ...

# %%
this_target  = "IceWaterOutletTemperature"
temp = df_temp[(df_temp['Name']== check_name_string_4)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterOutletTemperature = Item_string_4+"_"+this_target
temp[temp_string_IceWaterOutletTemperature] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterOutletTemperature = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterOutletTemperature.head())
    print(temp_df_IceWaterOutletTemperature.shape)
temp_df_IceWaterOutletTemperature = temp_df_IceWaterOutletTemperature.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterOutletTemperature.head())
print(temp_df_IceWaterOutletTemperature.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller04_IceWaterOutletTemperature
# 0 2019-06-18 21:00:00                                  1.0
# 1 2019-06-18 21:05:00                                  1.0
# 2 2019-06-18 21:10:00                                  1.0
# ...

# %%
this_target  = "IceWaterControl"
temp = df_temp[(df_temp['Name']== check_name_string_4)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterControl = Item_string_4+"_"+this_target
temp[temp_string_IceWaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterControl = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterControl.head())
    print(temp_df_IceWaterControl.shape)
temp_df_IceWaterControl = temp_df_IceWaterControl.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterControl.head())
print(temp_df_IceWaterControl.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機4  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller04_IceWaterControl
# 0 2019-06-18 21:00:00                        1.0
# 1 2019-06-18 21:05:00                        1.0
# 2 2019-06-18 21:10:00                        1.0
# ...

# %%
temp = temp_df_Return_Temperature
temp = pd.merge(temp,temp_df_ChillerOnOff)
temp = pd.merge(temp,temp_df_IceWaterOutletTemperature)
temp = pd.merge(temp,temp_df_IceWaterControl)

# %%
x = temp['Date_Time'] 
y = temp[temp_string_Return_Temperature]
y1= temp[temp_string_ChillerOnOff]
y2= temp[temp_string_IceWaterOutletTemperature]
y3= temp[temp_string_IceWaterControl]

fig = plt.figure(figsize=(20,12))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title_4)
a1.plot(x,y,label=temp_string_Return_Temperature)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_ChillerOnOff)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_IceWaterOutletTemperature)
a1.legend()

a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_IceWaterControl )
a1.legend()


if(debug_save_img):
    img_num = img_num+1
#     temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    temp = target_factory+'_'+Item_string_4+'_'+str(img_num)
    fig.savefig(fname = temp)

# %%
this_target  = "ChillerOnOff"
temp = df_temp[(df_temp['Name']== check_name_string_7)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_ChillerOnOff = Item_string_7+"_"+this_target
temp[temp_string_ChillerOnOff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_ChillerOnOff = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_ChillerOnOff.head())
    print(temp_df_ChillerOnOff.shape)
temp_df_ChillerOnOff = temp_df_ChillerOnOff.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_ChillerOnOff.head())
print(temp_df_ChillerOnOff.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller07_ChillerOnOff
# 0 2019-06-18 21:00:00                     1.0
# 1 2019-06-18 21:05:00                     1.0
# 2 2019-06-18 21:10:00                     1.0
# 3 2019-06-18 21:15:00                     1.0
# ...

# %%
this_target  = "IceWaterOutletTemperature"
temp = df_temp[(df_temp['Name']== check_name_string_7)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterOutletTemperature = Item_string_7+"_"+this_target
temp[temp_string_IceWaterOutletTemperature] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterOutletTemperature = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterOutletTemperature.head())
    print(temp_df_IceWaterOutletTemperature.shape)
temp_df_IceWaterOutletTemperature = temp_df_IceWaterOutletTemperature.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterOutletTemperature.head())
print(temp_df_IceWaterOutletTemperature.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller07_IceWaterOutletTemperature
# 0 2019-06-18 21:00:00                                  1.0
# 1 2019-06-18 21:05:00                                  1.0
# 2 2019-06-18 21:10:00                                  1.0
# ...

# %%
this_target  = "IceWaterControl"
temp = df_temp[(df_temp['Name']== check_name_string_7)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_IceWaterControl = Item_string_7+"_"+this_target
temp[temp_string_IceWaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp_df_IceWaterControl = temp[(temp['Type']==this_target)].reset_index(drop=True)
if(debug_print):
    print(temp_df_IceWaterControl.head())
    print(temp_df_IceWaterControl.shape)
temp_df_IceWaterControl = temp_df_IceWaterControl.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_IceWaterControl.head())
print(temp_df_IceWaterControl.shape)
# Out:
#         Name          Type  Value  Unit        Date   Time
# 0  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:20
# (594, 6)
#         Name          Type  Value  Unit        Date   Time  \
# 0  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:00
# 1  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:05
# 2  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:10
# 3  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:15
# 4  F1,2冰水主機7  ChillerOnOff    1.0   NaN  2019/06/18  21:20
#
#             Date_Time  Chiller07_IceWaterControl
# 0 2019-06-18 21:00:00                        1.0
# 1 2019-06-18 21:05:00                        1.0
# 2 2019-06-18 21:10:00                        1.0
# ...

# %%
temp = temp_df_Return_Temperature
temp = pd.merge(temp,temp_df_ChillerOnOff)
temp = pd.merge(temp,temp_df_IceWaterOutletTemperature)
temp = pd.merge(temp,temp_df_IceWaterControl)

# %%
x = temp['Date_Time'] 
y = temp[temp_string_Return_Temperature]
y1= temp[temp_string_ChillerOnOff]
y2= temp[temp_string_IceWaterOutletTemperature]
y3= temp[temp_string_IceWaterControl]

fig = plt.figure(figsize=(20,12))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title_7)
a1.plot(x,y,label=temp_string_Return_Temperature)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_ChillerOnOff)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_IceWaterOutletTemperature)
a1.legend()

a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_IceWaterControl )
a1.legend()


if(debug_save_img):
    img_num = img_num+1
#     temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    temp = target_factory+'_'+Item_string_7+'_'+str(img_num)
    fig.savefig(fname = temp)
