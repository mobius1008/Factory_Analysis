# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# path = 'F132FAHU01/'
# target = "F13 2F "
target_factory = 'F13'
floor = '2F'
target_string = "AHU06"
# file_name = path +'ST.csv'
# df_ST = pd.read_csv(file_name)
# # df_ST = pd.read_csv('F132FAHU05/ST.csv')

# %%
debug_print = 1
debug_save_img = 1
img_num = 0

# %%
# target_string_temp = target + target_string
target_string_temp = target_factory+' '+floor+' '+target_string
plot_title = target_string_temp
print("target_string_temp =",target_string_temp)
# Out:
# target_string_temp = F13 2F AHU06

# %%
path = target_factory+floor+target_string+'/'
path
# Out:
# 'F132FAHU06/'

# %%
file_name = path +'FanStatus.csv'
df_FanStatus = pd.read_csv(file_name)
file_name = path +'FirstFilterPressureDiff.csv'
df_FirstFilterPressureDiff = pd.read_csv(file_name)
file_name = path +'SecondFilterPressureDiff.csv'
df_SecondFilterPressureDiff = pd.read_csv(file_name)
file_name = path +'FanMaintain.csv'
df_FanMaintain = pd.read_csv(file_name)
file_name = path +'FanFault.csv'
df_FanFault = pd.read_csv(file_name)
file_name = path +'FanManualAuto.csv'
df_FanManualAuto = pd.read_csv(file_name)
file_name = path +'FanOnOff.csv'
df_FanOnOff = pd.read_csv(file_name)
file_name = path +'FanOnOffDisplay.csv'
df_FanOnOffDisplay = pd.read_csv(file_name)
file_name = path +'FanPressureDiff.csv'
df_FanPressureDiff = pd.read_csv(file_name)

file_name = path +'FanHzControl.csv'
df_FanHzControl = pd.read_csv(file_name)
file_name = path +'FanHzControlDisplay.csv'
df_FanHzControlDisplay = pd.read_csv(file_name)
file_name = path +'FanHzFeedback.csv'
df_FanHzFeedback = pd.read_csv(file_name)
file_name = path +'FanHzManualAuto.csv'
df_FanHzManualAuto = pd.read_csv(file_name)

file_name = path +'FanHr.csv'
df_FanHr = pd.read_csv(file_name)
file_name = path +'FanMaintainHrSet.csv'
df_FanMaintainHrSet = pd.read_csv(file_name)


file_name = path +'MVPreCoolingControl.csv'
df_MVPreCoolingControl = pd.read_csv(file_name)
file_name = path +'MVPreCoolingControlDisplay.csv'
df_MVPreCoolingControlDisplay = pd.read_csv(file_name)
file_name = path +'MVPreCoolingFeedback.csv'
df_MVPreCoolingFeedback = pd.read_csv(file_name)
file_name = path +'MVPreCoolingManualAuto.csv'
df_MVPreCoolingManualAuto = pd.read_csv(file_name)

file_name = path +'MVIcewaterControl.csv'
df_MVIcewaterControl = pd.read_csv(file_name)
file_name = path +'MVIcewaterControlDisplay.csv'
df_MVIcewaterControlDisplay = pd.read_csv(file_name)
file_name = path +'MVIcewaterFeedback.csv'
df_MVIcewaterFeedback = pd.read_csv(file_name)
file_name = path +'MVIcewaterManualAuto.csv'
df_MVIcewaterManualAuto = pd.read_csv(file_name)

file_name = path +'MVHotwaterControl.csv'
df_MVHotwaterControl = pd.read_csv(file_name)
file_name = path +'MVHotwaterControlDisplay.csv'
df_MVHotwaterControlDisplay = pd.read_csv(file_name)
file_name = path +'MVHotwaterFeedback.csv'
df_MVHotwaterFeedback = pd.read_csv(file_name)
file_name = path +'MVHotwaterManualAuto.csv'
df_MVHotwaterManualAuto = pd.read_csv(file_name)

file_name = path +'MVVaporControl.csv'
df_MVVaporControl = pd.read_csv(file_name)
file_name = path +'MVVaporControlDisplay.csv'
df_MVVaporControlDisplay = pd.read_csv(file_name)
file_name = path +'MVVaporFeedback.csv'
df_MVVaporFeedback = pd.read_csv(file_name)
file_name = path +'MVVaporManualAuto.csv'
df_MVVaporManualAuto = pd.read_csv(file_name)

file_name = path +'OAVControl.csv'
df_OAVControl = pd.read_csv(file_name)
file_name = path +'OAVControlDisplay.csv'
df_OAVControlDisplay = pd.read_csv(file_name)
file_name = path +'OAVFeedback.csv'
df_OAVFeedback = pd.read_csv(file_name)
file_name = path +'OAVManualAuto.csv'
df_OAVManualAuto = pd.read_csv(file_name)

file_name = path +'RAVControl.csv'
df_RAVControl = pd.read_csv(file_name)
file_name = path +'RAVControlDisplay.csv'
df_RAVControlDisplay = pd.read_csv(file_name)
file_name = path +'RAVFeedback.csv'
df_RAVFeedback = pd.read_csv(file_name)
file_name = path +'RAVManualAuto.csv'
df_RAVManualAuto = pd.read_csv(file_name)


file_name = path +'RATCutTempSet.csv'
df_RATCutTempSet = pd.read_csv(file_name)
file_name = path +'RATTemp.csv'
df_RATTemp = pd.read_csv(file_name)
file_name = path +'RATHumidity.csv'
df_RATHumidity = pd.read_csv(file_name)
file_name = path +'RATHumiditySet.csv'
df_RATHumiditySet = pd.read_csv(file_name)
file_name = path +'RATCutHumiditySet.csv'
df_RATCutHumiditySet = pd.read_csv(file_name)

file_name = path +'PreCoolingTemp.csv'
df_PreCoolingTemp = pd.read_csv(file_name)
file_name = path +'PreCoolingTempSet.csv'
df_PreCoolingTempSet = pd.read_csv(file_name)

file_name = path +'RP.csv'
df_RP = pd.read_csv(file_name)

file_name = path +'SAS.csv'
df_SAS = pd.read_csv(file_name)
file_name = path +'SH.csv'
df_SH = pd.read_csv(file_name)
file_name = path +'SP.csv'
df_SP = pd.read_csv(file_name)
file_name = path +'SPSet.csv'
df_SPSet = pd.read_csv(file_name)
file_name = path +'ST.csv'
df_ST = pd.read_csv(file_name)
file_name = path +'STSet.csv'
df_STSet = pd.read_csv(file_name)

file_name = path +'SVControl.csv'
df_SVControl = pd.read_csv(file_name)
file_name = path +'SVControlDisplay.csv'
df_SVControlDisplay = pd.read_csv(file_name)
file_name = path +'SVFeedback.csv'
df_SVFeedback = pd.read_csv(file_name)
file_name = path +'SVManualAuto.csv'
df_SVManualAuto = pd.read_csv(file_name)

# %%
print(df_FanHzFeedback.head())
print(df_FanHzFeedback.shape)
# Out:
#            Name           Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  FanHzFeedback  20.8834   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzFeedback  20.7116   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzFeedback  20.2663   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzFeedback  20.8699   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzFeedback  20.8066   NaN  2019/05/27  15:15
# (4064, 6)

# %% [markdown]
# ST

# %%
this_target  = "ST"
temp = df_ST[(df_ST['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_ST = target_string+"_"+this_target
temp[temp_string_ST] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_ST = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_ST.head())
print(temp_df_ST.shape)
# Out:
#            Name Type    Value  Unit        Date   Time
# 0  F13 2F AHU06   ST  21.7040   NaN  2019/05/27  14:25
# 1  F13 2F AHU06   ST  22.9722   NaN  2019/05/27  15:00
# 2  F13 2F AHU06   ST  22.7394   NaN  2019/05/27  15:05
# 3  F13 2F AHU06   ST  23.0129   NaN  2019/05/27  15:10
# 4  F13 2F AHU06   ST  22.9926   NaN  2019/05/27  15:15
# (4063, 6)
#            Name Type    Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06   ST  21.7040   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06   ST  22.9722   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06   ST  22.7394   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06   ST  23.0129   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06   ST  22.9926   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_ST
# 0   21.7040
# 1   22.9722
# 2   22.7394
# 3   23.0129
# 4   22.9926
# (4063, 8)
#             Date_Time  AHU06_ST
# 0 2019-05-27 14:25:00   21.7040
# ...

# %% [markdown]
# SH

# %%
this_target  = "SH"
temp = df_SH[(df_SH['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SH = target_string+"_"+this_target
temp[temp_string_SH] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SH = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)

print(temp_df_SH.head())
print(temp_df_SH.shape)
# Out:
#            Name Type    Value  Unit        Date   Time
# 0  F13 2F AHU06   SH  81.4359   NaN  2019/05/27  14:25
# 1  F13 2F AHU06   SH  73.1757   NaN  2019/05/27  15:00
# 2  F13 2F AHU06   SH  73.5555   NaN  2019/05/27  15:05
# 3  F13 2F AHU06   SH  71.7153   NaN  2019/05/27  15:10
# 4  F13 2F AHU06   SH  70.3771   NaN  2019/05/27  15:15
# (4064, 6)
#            Name Type    Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06   SH  81.4359   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06   SH  73.1757   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06   SH  73.5555   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06   SH  71.7153   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06   SH  70.3771   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_SH
# 0   81.4359
# 1   73.1757
# 2   73.5555
# 3   71.7153
# 4   70.3771
# (4064, 8)
#             Date_Time  AHU06_SH
# 0 2019-05-27 14:25:00   81.4359
# ...

# %% [markdown]
# FirstFilterPressureDiff

# %%
this_target  = "FirstFilterPressureDiff"
temp = df_FirstFilterPressureDiff[(df_FirstFilterPressureDiff['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FirstFilterPressureDiff = target_string+"_"+this_target
temp[temp_string_FirstFilterPressureDiff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FirstFilterPressureDiff = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FirstFilterPressureDiff.head())
print(temp_df_FirstFilterPressureDiff.shape)
# Out:
#            Name                     Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                     Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FirstFilterPressureDiff      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FirstFilterPressureDiff
# ...

# %% [markdown]
# SecondFilterPressureDiff

# %%
this_target  = "SecondFilterPressureDiff"
temp = df_SecondFilterPressureDiff[(df_SecondFilterPressureDiff['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SecondFilterPressureDiff = target_string+"_"+this_target
temp[temp_string_SecondFilterPressureDiff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SecondFilterPressureDiff = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SecondFilterPressureDiff.head())
print(temp_df_SecondFilterPressureDiff.shape)
# Out:
#            Name                      Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:15
# (4062, 6)
#            Name                      Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SecondFilterPressureDiff      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_SecondFilterPressureDiff
# ...

# %% [markdown]
# FanMaintain

# %%
this_target  = "FanMaintain"
temp = df_FanMaintain[(df_FanMaintain['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanMaintain = target_string+"_"+this_target
temp[temp_string_FanMaintain] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanMaintain = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanMaintain.head())
print(temp_df_FanMaintain.shape)
# Out:
#            Name         Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:15
# (4065, 6)
#            Name         Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanMaintain      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanMaintain
# 0 2019-05-27 14:25:00                  0
# 1 2019-05-27 15:00:00                  0
# 2 2019-05-27 15:05:00                  0
# 3 2019-05-27 15:10:00                  0
# ...

# %% [markdown]
# FanFault

# %%
this_target  = "FanFault"
temp = df_FanFault[(df_FanFault['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanFault = target_string+"_"+this_target
temp[temp_string_FanFault] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanFault = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanFault.head())
print(temp_df_FanFault.shape)
# Out:
#            Name      Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanFault      0   NaN  2019/05/27  07:35
# 1  F13 2F AHU06  FanFault      0   NaN  2019/05/27  14:25
# 2  F13 2F AHU06  FanFault      0   NaN  2019/05/27  15:00
# 3  F13 2F AHU06  FanFault      0   NaN  2019/05/27  15:05
# 4  F13 2F AHU06  FanFault      0   NaN  2019/05/27  15:10
# (4065, 6)
#            Name      Type  Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06  FanFault      0   NaN  2019/05/27  07:35 2019-05-27 07:35:00
# 1  F13 2F AHU06  FanFault      0   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 2  F13 2F AHU06  FanFault      0   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 3  F13 2F AHU06  FanFault      0   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 4  F13 2F AHU06  FanFault      0   NaN  2019/05/27  15:10 2019-05-27 15:10:00
#
#    AHU06_FanFault
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# (4065, 8)
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_FirstFilterPressureDiff)
temp = pd.merge(temp,temp_df_SecondFilterPressureDiff)
temp = pd.merge(temp,temp_df_FanMaintain)
temp = pd.merge(temp,temp_df_FanFault)
print(temp.head())
temp_All = temp
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_FirstFilterPressureDiff  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                              0
# 1 2019-05-27 15:00:00   22.9722   73.1757                              0
# 2 2019-05-27 15:05:00   22.7394   73.5555                              0
# 3 2019-05-27 15:10:00   23.0129   71.7153                              0
# 4 2019-05-27 15:15:00   22.9926   70.3771                              0
#
#    AHU06_SecondFilterPressureDiff  AHU06_FanMaintain  AHU06_FanFault
# 0                               1                  0               0
# 1                               1                  0               0
# 2                               1                  0               0
# 3                               1                  0               0
# 4                               1                  0               0

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_FirstFilterPressureDiff]
y3= temp[temp_string_SecondFilterPressureDiff]
y4= temp[temp_string_FanMaintain]
y5= temp[temp_string_FanFault]


fig = plt.figure(figsize=(20,12))

a1=plt.subplot(3,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(3,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(3,1,3)
a1.plot(x,y2,label=temp_string_FirstFilterPressureDiff)
a1.plot(x,y3,label=temp_string_SecondFilterPressureDiff)
a1.plot(x,y4,label=temp_string_FanMaintain)
a1.plot(x,y5,label=temp_string_FanFault)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# FanManualAuto

# %%
this_target  = "FanManualAuto"
temp = df_FanManualAuto[(df_FanManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanManualAuto = target_string+"_"+this_target
temp[temp_string_FanManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanManualAuto.head())
print(temp_df_FanManualAuto.shape)
# Out:
#            Name           Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name           Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanManualAuto      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanManualAuto
# 0 2019-05-27 14:25:00                    0
# 1 2019-05-27 15:00:00                    0
# 2 2019-05-27 15:05:00                    0
# ...

# %% [markdown]
# FanOnOff

# %%
this_target  = "FanOnOff"
temp = df_FanOnOff[(df_FanOnOff['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanOnOff = target_string+"_"+this_target
temp[temp_string_FanOnOff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanOnOff = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanOnOff.head())
print(temp_df_FanOnOff.shape)
# Out:
#            Name      Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:15
# (4065, 6)
#            Name      Type  Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06  FanOnOff      1   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_FanOnOff
# 0               1
# 1               1
# 2               1
# 3               1
# 4               1
# (4065, 8)
# ...

# %% [markdown]
# FanOnOffDisplay

# %%
this_target  = "FanOnOffDisplay"
temp = df_FanOnOffDisplay[(df_FanOnOffDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanOnOffDisplay = target_string+"_"+this_target
temp[temp_string_FanOnOffDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanOnOffDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanOnOffDisplay.head())
print(temp_df_FanOnOffDisplay.shape)
# Out:
#            Name             Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:15
# (4062, 6)
#            Name             Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanOnOffDisplay      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanOnOffDisplay
# 0 2019-05-27 14:25:00                      1
# 1 2019-05-27 15:00:00                      1
# ...

# %% [markdown]
# FanPressureDiff

# %%
this_target  = "FanPressureDiff"
temp = df_FanPressureDiff[(df_FanPressureDiff['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanPressureDiff = target_string+"_"+this_target
temp[temp_string_FanPressureDiff] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanPressureDiff = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanPressureDiff.head())
print(temp_df_FanPressureDiff.shape)
# Out:
#            Name             Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:15
# (4062, 6)
#            Name             Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanPressureDiff      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanPressureDiff
# 0 2019-05-27 14:25:00                      1
# 1 2019-05-27 15:00:00                      1
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_FanManualAuto)
temp = pd.merge(temp,temp_df_FanOnOff)
temp = pd.merge(temp,temp_df_FanOnOffDisplay)
temp = pd.merge(temp,temp_df_FanPressureDiff)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_FanManualAuto  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                    0
# 1 2019-05-27 15:00:00   22.9722   73.1757                    0
# 2 2019-05-27 15:05:00   22.7394   73.5555                    0
# 3 2019-05-27 15:10:00   23.0129   71.7153                    0
# 4 2019-05-27 15:15:00   22.9926   70.3771                    0
#
#    AHU06_FanOnOff  AHU06_FanOnOffDisplay  AHU06_FanPressureDiff
# 0               1                      1                      1
# 1               1                      1                      1
# 2               1                      1                      1
# 3               1                      1                      1
# 4               1                      1                      1

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_FanManualAuto]
y3= temp[temp_string_FanOnOff]
y4= temp[temp_string_FanOnOffDisplay]
y5= temp[temp_string_FanPressureDiff]


fig = plt.figure(figsize=(20,9))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(4,1,3)
a1.plot(x,y2,label=temp_string_FanManualAuto)
a1=plt.subplot(4,1,4)
a1.plot(x,y3,label=temp_string_FanOnOff)
a1.plot(x,y4,label=temp_string_FanOnOffDisplay)
a1.plot(x,y5,label=temp_string_FanPressureDiff)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# FanHzFeedback

# %%
this_target  = "FanHzFeedback"
temp = df_FanHzFeedback[(df_FanHzFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanHzFeedback = target_string+"_"+this_target
temp[temp_string_FanHzFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanHzFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanHzFeedback.head())
print(temp_df_FanHzFeedback.shape)
# Out:
#            Name           Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  FanHzFeedback  20.8834   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzFeedback  20.7116   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzFeedback  20.2663   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzFeedback  20.8699   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzFeedback  20.8066   NaN  2019/05/27  15:15
# (4064, 6)
#            Name           Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanHzFeedback  20.8834   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzFeedback  20.7116   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzFeedback  20.2663   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzFeedback  20.8699   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzFeedback  20.8066   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanHzFeedback
# 0 2019-05-27 14:25:00              20.8834
# 1 2019-05-27 15:00:00              20.7116
# ...

# %% [markdown]
# FanHzControl

# %%
this_target  = "FanHzControl"
temp = df_FanHzControl[(df_FanHzControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanHzControl = target_string+"_"+this_target
temp[temp_string_FanHzControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanHzControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanHzControl.head())
print(temp_df_FanHzControl.shape)
# Out:
#            Name          Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:15
# (4064, 6)
#            Name          Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzControl     30   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanHzControl
# 0 2019-05-27 14:25:00                  30
# 1 2019-05-27 15:00:00                  30
# 2 2019-05-27 15:05:00                  30
# ...

# %% [markdown]
# FanHzControlDisplay

# %%
this_target  = "FanHzControlDisplay"
temp = df_FanHzControlDisplay[(df_FanHzControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanHzControlDisplay = target_string+"_"+this_target
temp[temp_string_FanHzControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanHzControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanHzControlDisplay.head())
print(temp_df_FanHzControlDisplay.shape)
# Out:
#            Name                 Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:15
# (4062, 6)
#            Name                 Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzControlDisplay  30.0004   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanHzControlDisplay
# 0 2019-05-27 14:25:00                    30.0004
# ...

# %% [markdown]
# FanHzManualAuto

# %%
this_target  = "FanHzManualAuto"
temp = df_FanHzManualAuto[(df_FanHzManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanHzManualAuto = target_string+"_"+this_target
temp[temp_string_FanHzManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanHzManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanHzManualAuto.head())
print(temp_df_FanHzManualAuto.shape)
# Out:
#            Name             Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:15
# (4065, 6)
#            Name             Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHzManualAuto      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanHzManualAuto
# 0 2019-05-27 14:25:00                      1
# 1 2019-05-27 15:00:00                      1
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_FanHzFeedback)
temp = pd.merge(temp,temp_df_FanHzControl)
temp = pd.merge(temp,temp_df_FanHzControlDisplay)
temp = pd.merge(temp,temp_df_FanHzManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_FanHzFeedback  \
# 0 2019-05-27 14:25:00   21.7040   81.4359              20.8834
# 1 2019-05-27 15:00:00   22.9722   73.1757              20.7116
# 2 2019-05-27 15:05:00   22.7394   73.5555              20.2663
# 3 2019-05-27 15:10:00   23.0129   71.7153              20.8699
# 4 2019-05-27 15:15:00   22.9926   70.3771              20.8066
#
#    AHU06_FanHzControl  AHU06_FanHzControlDisplay  AHU06_FanHzManualAuto
# 0                  30                    30.0004                      1
# 1                  30                    30.0004                      1
# 2                  30                    30.0004                      1
# 3                  30                    30.0004                      1
# 4                  30                    30.0004                      1

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_FanHzManualAuto]
y3= temp[temp_string_FanHzFeedback]
y4= temp[temp_string_FanHzControl]
y5= temp[temp_string_FanHzControlDisplay]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_FanHzManualAuto)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_FanHzFeedback)
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_FanHzControl)
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_FanHzControlDisplay)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# FanHr

# %%
this_target  = "FanHr"
temp = df_FanHr[(df_FanHr['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanHr = target_string+"_"+this_target
temp[temp_string_FanHr] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanHr = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanHr.head())
print(temp_df_FanHr.shape)
# Out:
#            Name   Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanHr   5203   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:15
# (4064, 6)
#            Name   Type  Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06  FanHr   5203   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06  FanHr   5204   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_FanHr
# 0         5203
# 1         5204
# 2         5204
# 3         5204
# 4         5204
# (4064, 8)
#             Date_Time  AHU06_FanHr
# ...

# %% [markdown]
# FanMaintainHrSet

# %%
this_target  = "FanMaintainHrSet"
temp = df_FanMaintainHrSet[(df_FanMaintainHrSet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_FanMaintainHrSet = target_string+"_"+this_target
temp[temp_string_FanMaintainHrSet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_FanMaintainHrSet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_FanMaintainHrSet.head())
print(temp_df_FanMaintainHrSet.shape)
# Out:
#            Name              Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:15
# (4062, 6)
#            Name              Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  FanMaintainHrSet   5400   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_FanMaintainHrSet
# 0 2019-05-27 14:25:00                    5400
# 1 2019-05-27 15:00:00                    5400
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_FanHr)
temp = pd.merge(temp,temp_df_FanMaintainHrSet)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_FanHr  AHU06_FanMaintainHrSet
# 0 2019-05-27 14:25:00   21.7040   81.4359         5203                    5400
# 1 2019-05-27 15:00:00   22.9722   73.1757         5204                    5400
# 2 2019-05-27 15:05:00   22.7394   73.5555         5204                    5400
# 3 2019-05-27 15:10:00   23.0129   71.7153         5204                    5400
# 4 2019-05-27 15:15:00   22.9926   70.3771         5204                    5400

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_FanHr]
y3= temp[temp_string_FanMaintainHrSet]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_FanHr)
a1.legend()
a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_FanMaintainHrSet)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# PreCoolingTemp

# %%
this_target  = "PreCoolingTemp"
temp = df_PreCoolingTemp[(df_PreCoolingTemp['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_PreCoolingTemp = target_string+"_"+this_target
temp[temp_string_PreCoolingTemp] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_PreCoolingTemp = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_PreCoolingTemp.head())
print(temp_df_PreCoolingTemp.shape)
# Out:
#            Name            Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  PreCoolingTemp  22.8728   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  PreCoolingTemp  23.2548   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  PreCoolingTemp  23.1915   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  PreCoolingTemp  23.2616   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  PreCoolingTemp  23.0740   NaN  2019/05/27  15:15
# (4062, 6)
#            Name            Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  PreCoolingTemp  22.8728   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  PreCoolingTemp  23.2548   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  PreCoolingTemp  23.1915   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  PreCoolingTemp  23.2616   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  PreCoolingTemp  23.0740   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_PreCoolingTemp
# 0 2019-05-27 14:25:00               22.8728
# 1 2019-05-27 15:00:00               23.2548
# ...

# %% [markdown]
# PreCoolingTempSet

# %%
this_target  = "PreCoolingTempSet"
temp = df_PreCoolingTempSet[(df_PreCoolingTempSet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_PreCoolingTempSet = target_string+"_"+this_target
temp[temp_string_PreCoolingTempSet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_PreCoolingTempSet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_PreCoolingTempSet.head())
print(temp_df_PreCoolingTempSet.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:15
# (4064, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  PreCoolingTempSet     18   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_PreCoolingTempSet
# 0 2019-05-27 14:25:00                       18
# 1 2019-05-27 15:00:00                       18
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_PreCoolingTemp)
temp = pd.merge(temp,temp_df_PreCoolingTempSet)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_PreCoolingTemp  \
# 0 2019-05-27 14:25:00   21.7040   81.4359               22.8728
# 1 2019-05-27 15:00:00   22.9722   73.1757               23.2548
# 2 2019-05-27 15:05:00   22.7394   73.5555               23.1915
# 3 2019-05-27 15:10:00   23.0129   71.7153               23.2616
# 4 2019-05-27 15:15:00   22.9926   70.3771               23.0740
#
#    AHU06_PreCoolingTempSet
# 0                       18
# 1                       18
# 2                       18
# 3                       18
# 4                       18

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_PreCoolingTemp]
y3= temp[temp_string_PreCoolingTempSet ]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_PreCoolingTemp)
a1.legend()
a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_PreCoolingTempSet )
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# MVPreCoolingControl

# %%
this_target  = "MVPreCoolingControl"
temp = df_MVPreCoolingControl[(df_MVPreCoolingControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVPreCoolingControl = target_string+"_"+this_target
temp[temp_string_MVPreCoolingControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVPreCoolingControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVPreCoolingControl.head())
print(temp_df_MVPreCoolingControl.shape)
# Out:
#            Name                 Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                 Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingControl      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVPreCoolingControl
# 0 2019-05-27 14:25:00                          0
# ...

# %% [markdown]
# MVPreCoolingControlDisplay

# %%
this_target  = "MVPreCoolingControlDisplay"
temp = df_MVPreCoolingControlDisplay[(df_MVPreCoolingControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVPreCoolingControlDisplay = target_string+"_"+this_target
temp[temp_string_MVPreCoolingControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVPreCoolingControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVPreCoolingControlDisplay.head())
print(temp_df_MVPreCoolingControlDisplay.shape)
# Out:
#            Name                        Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                        Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingControlDisplay    0.0   NaN  2019/05/27  15:15
#
# ...

# %% [markdown]
# MVPreCoolingFeedback

# %%
this_target  = "MVPreCoolingFeedback"
temp = df_MVPreCoolingFeedback[(df_MVPreCoolingFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVPreCoolingFeedback = target_string+"_"+this_target
temp[temp_string_MVPreCoolingFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVPreCoolingFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVPreCoolingFeedback.head())
print(temp_df_MVPreCoolingFeedback.shape)
# Out:
#            Name                  Type     Value  Unit        Date   Time
# 0  F13 2F AHU06  MVPreCoolingFeedback  0.411430   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingFeedback  0.926847   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingFeedback  1.469390   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingFeedback  0.411430   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingFeedback  0.700787   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                  Type     Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVPreCoolingFeedback  0.411430   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingFeedback  0.926847   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingFeedback  1.469390   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingFeedback  0.411430   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingFeedback  0.700787   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVPreCoolingFeedback
# ...

# %% [markdown]
# MVPreCoolingManualAuto

# %%
this_target  = "MVPreCoolingManualAuto"
temp = df_MVPreCoolingManualAuto[(df_MVPreCoolingManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVPreCoolingManualAuto = target_string+"_"+this_target
temp[temp_string_MVPreCoolingManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVPreCoolingManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVPreCoolingManualAuto.head())
print(temp_df_MVPreCoolingManualAuto.shape)
# Out:
#            Name                    Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                    Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVPreCoolingManualAuto      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVPreCoolingManualAuto
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_MVPreCoolingControl)
temp = pd.merge(temp,temp_df_MVPreCoolingControlDisplay)
temp = pd.merge(temp,temp_df_MVPreCoolingFeedback)
temp = pd.merge(temp,temp_df_MVPreCoolingManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_MVPreCoolingControl  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                          0
# 1 2019-05-27 15:00:00   22.9722   73.1757                          0
# 2 2019-05-27 15:05:00   22.7394   73.5555                          0
# 3 2019-05-27 15:10:00   23.0129   71.7153                          0
# 4 2019-05-27 15:15:00   22.9926   70.3771                          0
#
#    AHU06_MVPreCoolingControlDisplay  AHU06_MVPreCoolingFeedback  \
# 0                               0.0                    0.411430
# 1                               0.0                    0.926847
# 2                               0.0                    1.469390
# 3                               0.0                    0.411430
# 4                               0.0                    0.700787
#
#    AHU06_MVPreCoolingManualAuto
# 0                             1
# 1                             1
# 2                             1
# ...

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_MVPreCoolingFeedback]
y3= temp[temp_string_MVPreCoolingControl ]
y4= temp[temp_string_MVPreCoolingControlDisplay ]
y5= temp[temp_string_MVPreCoolingManualAuto ]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(4,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(4,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(4,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_MVPreCoolingFeedback)
a1.legend()
a1=plt.subplot(4,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_MVPreCoolingControl )
a1.plot(x,y4,label=temp_string_MVPreCoolingControlDisplay )
a1.plot(x,y5,label=temp_string_MVPreCoolingManualAuto )
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# MVIcewaterControlDisplay

# %%
this_target  = "MVIcewaterControlDisplay"
temp = df_MVIcewaterControlDisplay[(df_MVIcewaterControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVIcewaterControlDisplay = target_string+"_"+this_target
temp[temp_string_MVIcewaterControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVIcewaterControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVIcewaterControlDisplay.head())
print(temp_df_MVIcewaterControlDisplay.shape)
# Out:
#            Name                      Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  MVIcewaterControlDisplay  4.38730   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterControlDisplay  5.92810   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterControlDisplay  2.28588   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterControlDisplay  4.59346   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterControlDisplay  4.08348   NaN  2019/05/27  15:15
# (4062, 6)
#            Name                      Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVIcewaterControlDisplay  4.38730   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterControlDisplay  5.92810   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterControlDisplay  2.28588   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterControlDisplay  4.59346   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterControlDisplay  4.08348   NaN  2019/05/27  15:15
#
# ...

# %% [markdown]
# MVIcewaterControl

# %%
this_target  = "MVIcewaterControl"
temp = df_MVIcewaterControl[(df_MVIcewaterControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVIcewaterControl = target_string+"_"+this_target
temp[temp_string_MVIcewaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVIcewaterControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVIcewaterControl.head())
print(temp_df_MVIcewaterControl.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterControl      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVIcewaterControl
# 0 2019-05-27 14:25:00                        0
# 1 2019-05-27 15:00:00                        0
# ...

# %% [markdown]
# MVIcewaterFeedback

# %%
this_target  = "MVIcewaterFeedback"
temp = df_MVIcewaterFeedback[(df_MVIcewaterFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVIcewaterFeedback = target_string+"_"+this_target
temp[temp_string_MVIcewaterFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVIcewaterFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVIcewaterFeedback.head())
print(temp_df_MVIcewaterFeedback.shape)
# Out:
#            Name                Type     Value  Unit        Date   Time
# 0  F13 2F AHU06  MVIcewaterFeedback  5.864000   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterFeedback  0.759562   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterFeedback  1.614070   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterFeedback  0.619405   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterFeedback  0.605841   NaN  2019/05/27  15:15
# (4064, 6)
#            Name                Type     Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVIcewaterFeedback  5.864000   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterFeedback  0.759562   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterFeedback  1.614070   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterFeedback  0.619405   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterFeedback  0.605841   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVIcewaterFeedback
# 0 2019-05-27 14:25:00                  5.864000
# ...

# %% [markdown]
# MVIcewaterManualAuto

# %%
this_target  = "MVIcewaterManualAuto"
temp = df_MVIcewaterManualAuto[(df_MVIcewaterManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVIcewaterManualAuto = target_string+"_"+this_target
temp[temp_string_MVIcewaterManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVIcewaterManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVIcewaterManualAuto.head())
print(temp_df_MVIcewaterManualAuto.shape)
# Out:
#            Name                  Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:15
# (4064, 6)
#            Name                  Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVIcewaterManualAuto      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVIcewaterManualAuto
# 0 2019-05-27 14:25:00                           0
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_MVIcewaterControlDisplay)
temp = pd.merge(temp,temp_df_MVIcewaterControl)
temp = pd.merge(temp,temp_df_MVIcewaterFeedback)
temp = pd.merge(temp,temp_df_MVIcewaterManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_MVIcewaterControlDisplay  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                         4.38730
# 1 2019-05-27 15:00:00   22.9722   73.1757                         5.92810
# 2 2019-05-27 15:05:00   22.7394   73.5555                         2.28588
# 3 2019-05-27 15:10:00   23.0129   71.7153                         4.59346
# 4 2019-05-27 15:15:00   22.9926   70.3771                         4.08348
#
#    AHU06_MVIcewaterControl  AHU06_MVIcewaterFeedback  \
# 0                        0                  5.864000
# 1                        0                  0.759562
# 2                        0                  1.614070
# 3                        0                  0.619405
# 4                        0                  0.605841
#
#    AHU06_MVIcewaterManualAuto
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_MVIcewaterControlDisplay]
y3= temp[temp_string_MVIcewaterControl ]
y4= temp[temp_string_MVIcewaterFeedback ]
y5= temp[temp_string_MVIcewaterManualAuto ]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_MVIcewaterControlDisplay)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_MVIcewaterFeedback )
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_MVIcewaterControl )
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_MVIcewaterManualAuto)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# MVHotwaterControl

# %%
this_target  = "MVHotwaterControl"
temp = df_MVHotwaterControl[(df_MVHotwaterControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVHotwaterControl = target_string+"_"+this_target
temp[temp_string_MVHotwaterControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVHotwaterControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVHotwaterControl.head())
print(temp_df_MVHotwaterControl.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterControl      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVHotwaterControl
# 0 2019-05-27 14:25:00                        0
# 1 2019-05-27 15:00:00                        0
# ...

# %% [markdown]
# MVHotwaterControlDisplay

# %%
this_target  = "MVHotwaterControlDisplay"
temp = df_MVHotwaterControlDisplay[(df_MVHotwaterControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVHotwaterControlDisplay = target_string+"_"+this_target
temp[temp_string_MVHotwaterControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVHotwaterControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVHotwaterControlDisplay.head())
print(temp_df_MVHotwaterControlDisplay.shape)
# Out:
#            Name                      Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  MVHotwaterControlDisplay  97.2005   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterControlDisplay  72.2946   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterControlDisplay  71.5567   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterControlDisplay  64.5218   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterControlDisplay  59.6861   NaN  2019/05/27  15:15
# (4065, 6)
#            Name                      Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVHotwaterControlDisplay  97.2005   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterControlDisplay  72.2946   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterControlDisplay  71.5567   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterControlDisplay  64.5218   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterControlDisplay  59.6861   NaN  2019/05/27  15:15
#
# ...

# %% [markdown]
# MVHotwaterFeedback

# %%
this_target  = "MVHotwaterFeedback"
temp = df_MVHotwaterFeedback[(df_MVHotwaterFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVHotwaterFeedback = target_string+"_"+this_target
temp[temp_string_MVHotwaterFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVHotwaterFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVHotwaterFeedback.head())
print(temp_df_MVHotwaterFeedback.shape)
# Out:
#            Name                  Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                  Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVHotwaterFeedback
# 0 2019-05-27 14:25:00                         0
# ...

# %% [markdown]
# MVHotwaterManualAuto

# %%
this_target  = "MVHotwaterManualAuto"
temp = df_MVHotwaterManualAuto[(df_MVHotwaterManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVHotwaterManualAuto = target_string+"_"+this_target
temp[temp_string_MVHotwaterManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVHotwaterManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVHotwaterManualAuto.head())
print(temp_df_MVHotwaterManualAuto.shape)
# Out:
#            Name                  Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name                  Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVHotwaterManualAuto      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVHotwaterManualAuto
# 0 2019-05-27 14:25:00                           0
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_MVHotwaterControl)
temp = pd.merge(temp,temp_df_MVHotwaterControlDisplay)
temp = pd.merge(temp,temp_df_MVHotwaterFeedback)
temp = pd.merge(temp,temp_df_MVHotwaterManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_MVHotwaterControl  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                        0
# 1 2019-05-27 15:00:00   22.9722   73.1757                        0
# 2 2019-05-27 15:05:00   22.7394   73.5555                        0
# 3 2019-05-27 15:10:00   23.0129   71.7153                        0
# 4 2019-05-27 15:15:00   22.9926   70.3771                        0
#
#    AHU06_MVHotwaterControlDisplay  AHU06_MVHotwaterFeedback  \
# 0                         97.2005                         0
# 1                         72.2946                         0
# 2                         71.5567                         0
# 3                         64.5218                         0
# 4                         59.6861                         0
#
#    AHU06_MVHotwaterManualAuto
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           0

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_MVHotwaterControl]
y3= temp[temp_string_MVHotwaterControlDisplay ]
y4= temp[temp_string_MVHotwaterFeedback]
y5= temp[temp_string_MVHotwaterManualAuto ]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_MVHotwaterControl)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_MVHotwaterControlDisplay )
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_MVHotwaterFeedback )
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_MVHotwaterManualAuto)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# MVVaporControl

# %%
this_target  = "MVVaporControl"
temp = df_MVVaporControl[(df_MVVaporControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVVaporControl = target_string+"_"+this_target
temp[temp_string_MVVaporControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVVaporControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVVaporControl.head())
print(temp_df_MVVaporControl.shape)
# Out:
#            Name            Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name            Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporControl      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVVaporControl
# 0 2019-05-27 14:25:00                     0
# 1 2019-05-27 15:00:00                     0
# 2 2019-05-27 15:05:00                     0
# ...

# %% [markdown]
# MVVaporControlDisplay

# %%
this_target  = "MVVaporControlDisplay"
temp = df_MVVaporControlDisplay[(df_MVVaporControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVVaporControlDisplay = target_string+"_"+this_target
temp[temp_string_MVVaporControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVVaporControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVVaporControlDisplay.head())
print(temp_df_MVVaporControlDisplay.shape)
# Out:
#            Name                   Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name                   Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporControlDisplay      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVVaporControlDisplay
# 0 2019-05-27 14:25:00                            0
# ...

# %% [markdown]
# MVVaporFeedback

# %%
this_target  = "MVVaporFeedback"
temp = df_MVVaporFeedback[(df_MVVaporFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVVaporFeedback = target_string+"_"+this_target
temp[temp_string_MVVaporFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVVaporFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVVaporFeedback.head())
print(temp_df_MVVaporFeedback.shape)
# Out:
#            Name             Type     Value  Unit        Date   Time
# 0  F13 2F AHU06  MVVaporFeedback  0.115741   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporFeedback  0.086806   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporFeedback  0.126591   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporFeedback  0.119358   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporFeedback  0.090423   NaN  2019/05/27  15:15
# (4063, 6)
#            Name             Type     Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVVaporFeedback  0.115741   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporFeedback  0.086806   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporFeedback  0.126591   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporFeedback  0.119358   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporFeedback  0.090423   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVVaporFeedback
# 0 2019-05-27 14:25:00               0.115741
# 1 2019-05-27 15:00:00               0.086806
# ...

# %% [markdown]
# MVVaporManualAuto

# %%
this_target  = "MVVaporManualAuto"
temp = df_MVVaporManualAuto[(df_MVVaporManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_MVVaporManualAuto = target_string+"_"+this_target
temp[temp_string_MVVaporManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_MVVaporManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_MVVaporManualAuto.head())
print(temp_df_MVVaporManualAuto.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:15
# (4064, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  MVVaporManualAuto      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_MVVaporManualAuto
# 0 2019-05-27 14:25:00                        1
# 1 2019-05-27 15:00:00                        1
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_MVVaporControl)
temp = pd.merge(temp,temp_df_MVVaporControlDisplay)
temp = pd.merge(temp,temp_df_MVVaporFeedback)
temp = pd.merge(temp,temp_df_MVVaporManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_MVVaporControl  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                     0
# 1 2019-05-27 15:00:00   22.9722   73.1757                     0
# 2 2019-05-27 15:05:00   22.7394   73.5555                     0
# 3 2019-05-27 15:10:00   23.0129   71.7153                     0
# 4 2019-05-27 15:15:00   22.9926   70.3771                     0
#
#    AHU06_MVVaporControlDisplay  AHU06_MVVaporFeedback  AHU06_MVVaporManualAuto
# 0                            0               0.115741                        1
# 1                            0               0.086806                        1
# 2                            0               0.126591                        1
# 3                            0               0.119358                        1
# 4                            0               0.090423                        1

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_MVVaporControl]
y3= temp[temp_string_MVVaporControlDisplay ]
y4= temp[temp_string_MVVaporFeedback]
y5= temp[temp_string_MVVaporManualAuto]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_MVVaporControl)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_MVVaporControlDisplay )
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_MVVaporFeedback )
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_MVVaporManualAuto)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# OAVControl

# %%
this_target  = "OAVControl"
temp = df_OAVControl[(df_OAVControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_OAVControl = target_string+"_"+this_target
temp[temp_string_OAVControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_OAVControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_OAVControl.head())
print(temp_df_OAVControl.shape)
# Out:
#            Name        Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name        Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVControl      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_OAVControl
# 0 2019-05-27 14:25:00                 0
# 1 2019-05-27 15:00:00                 0
# 2 2019-05-27 15:05:00                 0
# 3 2019-05-27 15:10:00                 0
# ...

# %% [markdown]
# OAVControlDisplay

# %%
this_target  = "OAVControlDisplay"
temp = df_OAVControlDisplay[(df_OAVControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_OAVControlDisplay = target_string+"_"+this_target
temp[temp_string_OAVControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_OAVControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_OAVControlDisplay.head())
print(temp_df_OAVControlDisplay.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVControlDisplay    0.0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_OAVControlDisplay
# 0 2019-05-27 14:25:00                      0.0
# 1 2019-05-27 15:00:00                      0.0
# ...

# %% [markdown]
# OAVFeedback

# %%
this_target  = "OAVFeedback"
temp = df_OAVFeedback[(df_OAVFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_OAVFeedback = target_string+"_"+this_target
temp[temp_string_OAVFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_OAVFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_OAVFeedback.head())
print(temp_df_OAVFeedback.shape)
# Out:
#            Name         Type     Value  Unit        Date   Time
# 0  F13 2F AHU06  OAVFeedback  0.701678   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVFeedback  1.189960   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVFeedback  0.911458   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVFeedback  0.694444   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVFeedback  0.661892   NaN  2019/05/27  15:15
# (4064, 6)
#            Name         Type     Value  Unit        Date   Time  \
# 0  F13 2F AHU06  OAVFeedback  0.701678   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVFeedback  1.189960   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVFeedback  0.911458   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVFeedback  0.694444   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVFeedback  0.661892   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_OAVFeedback
# 0 2019-05-27 14:25:00           0.701678
# 1 2019-05-27 15:00:00           1.189960
# 2 2019-05-27 15:05:00           0.911458
# ...

# %% [markdown]
# OAVManualAuto

# %%
this_target  = "OAVManualAuto"
temp = df_OAVManualAuto[(df_OAVManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_OAVManualAuto = target_string+"_"+this_target
temp[temp_string_OAVManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_OAVManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_OAVManualAuto.head())
print(temp_df_OAVManualAuto.shape)
# Out:
#            Name           Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:15
# (4062, 6)
#            Name           Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  OAVManualAuto      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_OAVManualAuto
# 0 2019-05-27 14:25:00                    1
# 1 2019-05-27 15:00:00                    1
# 2 2019-05-27 15:05:00                    1
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_OAVControl)
temp = pd.merge(temp,temp_df_OAVControlDisplay)
temp = pd.merge(temp,temp_df_OAVFeedback)
temp = pd.merge(temp,temp_df_OAVManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_OAVControl  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                 0
# 1 2019-05-27 15:00:00   22.9722   73.1757                 0
# 2 2019-05-27 15:05:00   22.7394   73.5555                 0
# 3 2019-05-27 15:10:00   23.0129   71.7153                 0
# 4 2019-05-27 15:15:00   22.9926   70.3771                 0
#
#    AHU06_OAVControlDisplay  AHU06_OAVFeedback  AHU06_OAVManualAuto
# 0                      0.0           0.701678                    1
# 1                      0.0           1.189960                    1
# 2                      0.0           0.911458                    1
# 3                      0.0           0.694444                    1
# 4                      0.0           0.661892                    1

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_OAVControl]
y3= temp[temp_string_OAVControlDisplay ]
y4= temp[temp_string_OAVFeedback]
y5= temp[temp_string_OAVManualAuto]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_OAVControl)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_OAVControlDisplay )
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_OAVFeedback )
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_OAVManualAuto)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# RAVControl

# %%
this_target  = "RAVControl"
temp = df_RAVControl[(df_RAVControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RAVControl = target_string+"_"+this_target
temp[temp_string_RAVControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RAVControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RAVControl.head())
print(temp_df_RAVControl.shape)
# Out:
#            Name        Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:15
# (4065, 6)
#            Name        Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVControl    100   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RAVControl
# 0 2019-05-27 14:25:00               100
# 1 2019-05-27 15:00:00               100
# 2 2019-05-27 15:05:00               100
# 3 2019-05-27 15:10:00               100
# ...

# %% [markdown]
# RAVControlDisplay

# %%
this_target  = "RAVControlDisplay"
temp = df_RAVControlDisplay[(df_RAVControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RAVControlDisplay = target_string+"_"+this_target
temp[temp_string_RAVControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RAVControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RAVControlDisplay.head())
print(temp_df_RAVControlDisplay.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:15
# (4062, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVControlDisplay    100   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RAVControlDisplay
# 0 2019-05-27 14:25:00                      100
# 1 2019-05-27 15:00:00                      100
# ...

# %% [markdown]
# RAVFeedback

# %%
this_target  = "RAVFeedback"
temp = df_RAVFeedback[(df_RAVFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RAVFeedback = target_string+"_"+this_target
temp[temp_string_RAVFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RAVFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RAVFeedback.head())
print(temp_df_RAVFeedback.shape)
# Out:
#            Name         Type     Value  Unit        Date   Time
# 0  F13 2F AHU06  RAVFeedback   99.9892   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVFeedback  100.1450   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVFeedback  100.0580   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVFeedback  100.0000   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVFeedback  100.2640   NaN  2019/05/27  15:15
# (4067, 6)
#            Name         Type     Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RAVFeedback   99.9892   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVFeedback  100.1450   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVFeedback  100.0580   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVFeedback  100.0000   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVFeedback  100.2640   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RAVFeedback
# 0 2019-05-27 14:25:00            99.9892
# 1 2019-05-27 15:00:00           100.1450
# 2 2019-05-27 15:05:00           100.0580
# ...

# %% [markdown]
# RAVManualAuto

# %%
this_target  = "RAVManualAuto"
temp = df_RAVManualAuto[(df_RAVManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RAVManualAuto = target_string+"_"+this_target
temp[temp_string_RAVManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RAVManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RAVManualAuto.head())
print(temp_df_RAVManualAuto.shape)
# Out:
#            Name           Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:15
# (4065, 6)
#            Name           Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RAVManualAuto      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RAVManualAuto
# 0 2019-05-27 14:25:00                    0
# 1 2019-05-27 15:00:00                    0
# 2 2019-05-27 15:05:00                    0
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_RAVControl)
temp = pd.merge(temp,temp_df_RAVControlDisplay)
temp = pd.merge(temp,temp_df_RAVFeedback)
temp = pd.merge(temp,temp_df_RAVManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_RAVControl  \
# 0 2019-05-27 14:25:00   21.7040   81.4359               100
# 1 2019-05-27 15:00:00   22.9722   73.1757               100
# 2 2019-05-27 15:05:00   22.7394   73.5555               100
# 3 2019-05-27 15:10:00   23.0129   71.7153               100
# 4 2019-05-27 15:15:00   22.9926   70.3771               100
#
#    AHU06_RAVControlDisplay  AHU06_RAVFeedback  AHU06_RAVManualAuto
# 0                      100            99.9892                    0
# 1                      100           100.1450                    0
# 2                      100           100.0580                    0
# 3                      100           100.0000                    0
# 4                      100           100.2640                    0

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_RAVControl]
y3= temp[temp_string_RAVControlDisplay ]
y4= temp[temp_string_RAVFeedback]
y5= temp[temp_string_RAVManualAuto]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_RAVControl)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_RAVControlDisplay )
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_RAVFeedback )
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_RAVManualAuto)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# RATCutTempSet

# %%
this_target  = "RATCutTempSet"
temp = df_RATCutTempSet[(df_RATCutTempSet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RATCutTempSet = target_string+"_"+this_target
temp[temp_string_RATCutTempSet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RATCutTempSet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RATCutTempSet.head())
print(temp_df_RATCutTempSet.shape)
# Out:
#            Name           Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:15
# (4062, 6)
#            Name           Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATCutTempSet     35   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RATCutTempSet
# 0 2019-05-27 14:25:00                   35
# 1 2019-05-27 15:00:00                   35
# 2 2019-05-27 15:05:00                   35
# ...

# %% [markdown]
# RATTemp

# %%
this_target  = "RATTemp"
temp = df_RATTemp[(df_RATTemp['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RATTemp = target_string+"_"+this_target
temp[temp_string_RATTemp] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RATTemp = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RATTemp.head())
print(temp_df_RATTemp.shape)
# Out:
#            Name     Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  RATTemp  23.1667   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATTemp  23.4877   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATTemp  23.5510   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATTemp  23.5035   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATTemp  23.4537   NaN  2019/05/27  15:15
# (4064, 6)
#            Name     Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RATTemp  23.1667   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATTemp  23.4877   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATTemp  23.5510   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATTemp  23.5035   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATTemp  23.4537   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RATTemp
# 0 2019-05-27 14:25:00        23.1667
# 1 2019-05-27 15:00:00        23.4877
# 2 2019-05-27 15:05:00        23.5510
# 3 2019-05-27 15:10:00        23.5035
# 4 2019-05-27 15:15:00        23.4537
# (4064, 8)
# ...

# %% [markdown]
# RATHumidity

# %%
this_target  = "RATHumidity"
temp = df_RATHumidity[(df_RATHumidity['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RATHumidity = target_string+"_"+this_target
temp[temp_string_RATHumidity] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RATHumidity = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RATHumidity.head())
print(temp_df_RATHumidity.shape)
# Out:
#            Name         Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  RATHumidity  74.9842   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATHumidity  71.1321   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATHumidity  70.5670   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATHumidity  70.0425   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATHumidity  69.2694   NaN  2019/05/27  15:15
# (4064, 6)
#            Name         Type    Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RATHumidity  74.9842   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATHumidity  71.1321   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATHumidity  70.5670   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATHumidity  70.0425   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATHumidity  69.2694   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RATHumidity
# 0 2019-05-27 14:25:00            74.9842
# 1 2019-05-27 15:00:00            71.1321
# 2 2019-05-27 15:05:00            70.5670
# ...

# %% [markdown]
# RATHumiditySet

# %%
this_target  = "RATHumiditySet"
temp = df_RATHumiditySet[(df_RATHumiditySet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RATHumiditySet = target_string+"_"+this_target
temp[temp_string_RATHumiditySet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RATHumiditySet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RATHumiditySet.head())
print(temp_df_RATHumiditySet.shape)
# Out:
#            Name            Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:15
# (4065, 6)
#            Name            Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATHumiditySet     81   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RATHumiditySet
# 0 2019-05-27 14:25:00                    81
# 1 2019-05-27 15:00:00                    81
# 2 2019-05-27 15:05:00                    81
# ...

# %% [markdown]
# RATCutHumiditySet

# %%
this_target  = "RATCutHumiditySet"
temp = df_RATCutHumiditySet[(df_RATCutHumiditySet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RATCutHumiditySet = target_string+"_"+this_target
temp[temp_string_RATCutHumiditySet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RATCutHumiditySet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RATCutHumiditySet.head())
print(temp_df_RATCutHumiditySet.shape)
# Out:
#            Name               Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:15
# (4063, 6)
#            Name               Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  RATCutHumiditySet     70   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_RATCutHumiditySet
# 0 2019-05-27 14:25:00                       70
# 1 2019-05-27 15:00:00                       70
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_RATTemp)
temp = pd.merge(temp,temp_df_RATCutTempSet)
temp = pd.merge(temp,temp_df_RATHumidity)
temp = pd.merge(temp,temp_df_RATHumiditySet)
temp = pd.merge(temp,temp_df_RATCutHumiditySet)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_RATTemp  AHU06_RATCutTempSet  \
# 0 2019-05-27 14:25:00   21.7040   81.4359        23.1667                   35
# 1 2019-05-27 15:00:00   22.9722   73.1757        23.4877                   35
# 2 2019-05-27 15:05:00   22.7394   73.5555        23.5510                   35
# 3 2019-05-27 15:10:00   23.0129   71.7153        23.5035                   35
# 4 2019-05-27 15:15:00   22.9926   70.3771        23.4537                   35
#
#    AHU06_RATHumidity  AHU06_RATHumiditySet  AHU06_RATCutHumiditySet
# 0            74.9842                    81                       70
# 1            71.1321                    81                       70
# 2            70.5670                    81                       70
# 3            70.0425                    81                       70
# 4            69.2694                    81                       70

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_RATTemp]
y3= temp[temp_string_RATCutTempSet]
y4= temp[temp_string_RATHumidity]
y5= temp[temp_string_RATHumiditySet]
y6= temp[temp_string_RATCutHumiditySet]


fig = plt.figure(figsize=(20,21))

a1=plt.subplot(7,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(7,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(7,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_RATTemp)
a1.legend()
a1=plt.subplot(7,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_RATCutTempSet )
a1.legend()
a1=plt.subplot(7,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_RATHumidity )
a1.legend()
a1=plt.subplot(7,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_RATHumiditySet)
a1.legend()
a1=plt.subplot(7,1,7)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y6,label=temp_string_RATCutHumiditySet)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# SVControl

# %%
this_target  = "SVControl"
temp = df_SVControl[(df_SVControl['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SVControl = target_string+"_"+this_target
temp[temp_string_SVControl] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SVControl = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SVControl.head())
print(temp_df_SVControl.shape)
# Out:
#            Name       Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  SVControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name       Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  SVControl      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVControl      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_SVControl
# 0 2019-05-27 14:25:00                0
# 1 2019-05-27 15:00:00                0
# 2 2019-05-27 15:05:00                0
# 3 2019-05-27 15:10:00                0
# 4 2019-05-27 15:15:00                0
# ...

# %% [markdown]
# SVControlDisplay

# %%
this_target  = "SVControlDisplay"
temp = df_SVControlDisplay[(df_SVControlDisplay['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SVControlDisplay = target_string+"_"+this_target
temp[temp_string_SVControlDisplay] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SVControlDisplay = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SVControlDisplay.head())
print(temp_df_SVControlDisplay.shape)
# Out:
#            Name              Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:15
# (4062, 6)
#            Name              Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVControlDisplay      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_SVControlDisplay
# 0 2019-05-27 14:25:00                       0
# 1 2019-05-27 15:00:00                       0
# ...

# %% [markdown]
# SVFeedback

# %%
this_target  = "SVFeedback"
temp = df_SVFeedback[(df_SVFeedback['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SVFeedback = target_string+"_"+this_target
temp[temp_string_SVFeedback] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SVFeedback = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SVFeedback.head())
print(temp_df_SVFeedback.shape)
# Out:
#            Name        Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:15
# (4064, 6)
#            Name        Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVFeedback      0   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_SVFeedback
# 0 2019-05-27 14:25:00                 0
# 1 2019-05-27 15:00:00                 0
# 2 2019-05-27 15:05:00                 0
# 3 2019-05-27 15:10:00                 0
# ...

# %% [markdown]
# SVManualAuto

# %%
this_target  = "SVManualAuto"
temp = df_SVManualAuto[(df_SVManualAuto['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SVManualAuto = target_string+"_"+this_target
temp[temp_string_SVManualAuto] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SVManualAuto = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SVManualAuto.head())
print(temp_df_SVManualAuto.shape)
# Out:
#            Name          Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:15
# (4063, 6)
#            Name          Type  Value  Unit        Date   Time  \
# 0  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SVManualAuto      1   NaN  2019/05/27  15:15
#
#             Date_Time  AHU06_SVManualAuto
# 0 2019-05-27 14:25:00                   1
# 1 2019-05-27 15:00:00                   1
# 2 2019-05-27 15:05:00                   1
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_SVControl)
temp = pd.merge(temp,temp_df_SVControlDisplay)
temp = pd.merge(temp,temp_df_SVFeedback)
temp = pd.merge(temp,temp_df_SVManualAuto)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_SVControl  \
# 0 2019-05-27 14:25:00   21.7040   81.4359                0
# 1 2019-05-27 15:00:00   22.9722   73.1757                0
# 2 2019-05-27 15:05:00   22.7394   73.5555                0
# 3 2019-05-27 15:10:00   23.0129   71.7153                0
# 4 2019-05-27 15:15:00   22.9926   70.3771                0
#
#    AHU06_SVControlDisplay  AHU06_SVFeedback  AHU06_SVManualAuto
# 0                       0                 0                   1
# 1                       0                 0                   1
# 2                       0                 0                   1
# 3                       0                 0                   1
# 4                       0                 0                   1

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_SVControl]
y3= temp[temp_string_SVControlDisplay ]
y4= temp[temp_string_SVFeedback]
y5= temp[temp_string_SVManualAuto]


fig = plt.figure(figsize=(20,18))

a1=plt.subplot(6,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.legend()

a1=plt.subplot(6,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(6,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y2,label=temp_string_SVControl)
a1.legend()
a1=plt.subplot(6,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y4,label=temp_string_SVControlDisplay )
a1.legend()
a1=plt.subplot(6,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_SVFeedback )
a1.legend()
a1=plt.subplot(6,1,6)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_SVManualAuto)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %% [markdown]
# RP

# %%
this_target  = "RP"
temp = df_RP[(df_RP['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_RP = target_string+"_"+this_target
temp[temp_string_RP] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_RP = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_RP.head())
print(temp_df_RP.shape)
# Out:
#            Name Type  Value  Unit        Date   Time
# 0  F13 2F AHU06   RP      0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06   RP      0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06   RP      0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06   RP      0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06   RP      0   NaN  2019/05/27  15:15
# (4063, 6)
#            Name Type  Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06   RP      0   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06   RP      0   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06   RP      0   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06   RP      0   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06   RP      0   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_RP
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
# (4063, 8)
#             Date_Time  AHU06_RP
# 0 2019-05-27 14:25:00         0
# 1 2019-05-27 15:00:00         0
# ...

# %% [markdown]
# SAS

# %%
this_target  = "SAS"
temp = df_SAS[(df_SAS['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SAS = target_string+"_"+this_target
temp[temp_string_SAS] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SAS = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SAS.head())
print(temp_df_SAS.shape)
# Out:
#            Name Type    Value  Unit        Date   Time
# 0  F13 2F AHU06  SAS  6.96831   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SAS  5.94290   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SAS  7.31011   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SAS  6.70788   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SAS  6.47527   NaN  2019/05/27  15:15
# (4063, 6)
#            Name Type    Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06  SAS  6.96831   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06  SAS  5.94290   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06  SAS  7.31011   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06  SAS  6.70788   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06  SAS  6.47527   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_SAS
# 0    6.96831
# 1    5.94290
# 2    7.31011
# 3    6.70788
# 4    6.47527
# (4063, 8)
#             Date_Time  AHU06_SAS
# 0 2019-05-27 14:25:00    6.96831
# ...

# %% [markdown]
# SP

# %%
this_target  = "SP"
temp = df_SP[(df_SP['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SP = target_string+"_"+this_target
temp[temp_string_SP] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SP = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SP.head())
print(temp_df_SP.shape)
# Out:
#            Name Type    Value  Unit        Date   Time
# 0  F13 2F AHU06   SP  67.7729   NaN  2019/05/27  14:25
# 1  F13 2F AHU06   SP  67.1399   NaN  2019/05/27  15:00
# 2  F13 2F AHU06   SP  67.5920   NaN  2019/05/27  15:05
# 3  F13 2F AHU06   SP  67.1399   NaN  2019/05/27  15:10
# 4  F13 2F AHU06   SP  66.8686   NaN  2019/05/27  15:15
# (4063, 6)
#            Name Type    Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06   SP  67.7729   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06   SP  67.1399   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06   SP  67.5920   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06   SP  67.1399   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06   SP  66.8686   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_SP
# 0   67.7729
# 1   67.1399
# 2   67.5920
# 3   67.1399
# 4   66.8686
# (4063, 8)
#             Date_Time  AHU06_SP
# 0 2019-05-27 14:25:00   67.7729
# ...

# %% [markdown]
# SPSet

# %%
this_target  = "SPSet"
temp = df_SPSet[(df_SPSet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_SPSet = target_string+"_"+this_target
temp[temp_string_SPSet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_SPSet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_SPSet.head())
print(temp_df_SPSet.shape)
# Out:
#            Name   Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  SPSet    200   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:15
# (4062, 6)
#            Name   Type  Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06  SPSet    200   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06  SPSet    200   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_SPSet
# 0          200
# 1          200
# 2          200
# 3          200
# 4          200
# (4062, 8)
#             Date_Time  AHU06_SPSet
# ...

# %% [markdown]
# STSet

# %%
this_target  = "STSet"
temp = df_STSet[(df_STSet['Name']== target_string_temp)].reset_index(drop=True)
if(debug_print):
    print(temp.head())
    print(temp.shape)
temp['Date_Time'] = pd.to_datetime(temp['Date']+' '+temp['Time'])
temp_string_STSet = target_string+"_"+this_target
temp[temp_string_STSet] = temp['Value']
if(debug_print):
    print(temp.head())
    print(temp.shape)

temp_df_STSet = temp.drop(['Name','Type','Value','Unit','Date','Time'], axis=1)
print(temp_df_STSet.head())
print(temp_df_STSet.shape)
# Out:
#            Name   Type  Value  Unit        Date   Time
# 0  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  14:25
# 1  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:00
# 2  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:05
# 3  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:10
# 4  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:15
# (4064, 6)
#            Name   Type  Value  Unit        Date   Time           Date_Time  \
# 0  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  14:25 2019-05-27 14:25:00
# 1  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:00 2019-05-27 15:00:00
# 2  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:05 2019-05-27 15:05:00
# 3  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:10 2019-05-27 15:10:00
# 4  F13 2F AHU06  STSet   23.0   NaN  2019/05/27  15:15 2019-05-27 15:15:00
#
#    AHU06_STSet
# 0         23.0
# 1         23.0
# 2         23.0
# 3         23.0
# 4         23.0
# (4064, 8)
#             Date_Time  AHU06_STSet
# ...

# %%
temp = pd.merge(temp_df_ST,temp_df_SH)
temp = pd.merge(temp,temp_df_STSet)
temp = pd.merge(temp,temp_df_SP)
temp = pd.merge(temp,temp_df_SPSet)
temp = pd.merge(temp,temp_df_SAS)
temp = pd.merge(temp,temp_df_RP)
print(temp.head())
temp_All = pd.merge(temp_All,temp)
# Out:
#             Date_Time  AHU06_ST  AHU06_SH  AHU06_STSet  AHU06_SP  AHU06_SPSet  \
# 0 2019-05-27 14:25:00   21.7040   81.4359         23.0   67.7729          200
# 1 2019-05-27 15:00:00   22.9722   73.1757         23.0   67.1399          200
# 2 2019-05-27 15:05:00   22.7394   73.5555         23.0   67.5920          200
# 3 2019-05-27 15:10:00   23.0129   71.7153         23.0   67.1399          200
# 4 2019-05-27 15:15:00   22.9926   70.3771         23.0   66.8686          200
#
#    AHU06_SAS  AHU06_RP
# 0    6.96831         0
# 1    5.94290         0
# 2    7.31011         0
# 3    6.70788         0
# 4    6.47527         0

# %%
x = temp['Date_Time'] 
y = temp[temp_string_ST]
y1= temp[temp_string_SH]
y2= temp[temp_string_STSet]
y3= temp[temp_string_SP ]
y4= temp[temp_string_SPSet]
y5= temp[temp_string_SAS]
y6= temp[temp_string_RP]


fig = plt.figure(figsize=(20,15))

a1=plt.subplot(5,1,1)
plt.grid(color='r',linestyle='-.')
# plt.title(target)
plt.title(plot_title)
a1.plot(x,y,label=temp_string_ST)
a1.plot(x,y2,label=temp_string_STSet)
a1.legend()

a1=plt.subplot(5,1,2)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y1,label=temp_string_SH)
a1.legend()

a1=plt.subplot(5,1,3)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y3,label=temp_string_SP )
a1.plot(x,y4,label=temp_string_SPSet )
a1.legend()
a1=plt.subplot(5,1,4)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y5,label=temp_string_SAS)
a1.legend()

a1=plt.subplot(5,1,5)
plt.grid(color='r',linestyle='-.')
a1.plot(x,y6,label=temp_string_RP)
a1.legend()

if(debug_save_img):
    img_num = img_num+1
    temp = target_factory+'_'+floor+'_'+target_string+'_'+str(img_num)
    fig.savefig(fname = temp)

# %%
temp_All_corr = temp_All.drop(['Date_Time'], axis=1)

# %%
print(temp_All_corr.head())
print(temp_All_corr.shape)
# Out:
#    AHU06_ST  AHU06_SH  AHU06_FirstFilterPressureDiff  \
# 0   21.7040   81.4359                              0
# 1   22.9722   73.1757                              0
# 2   22.7394   73.5555                              0
# 3   23.0129   71.7153                              0
# 4   22.9926   70.3771                              0
#
#    AHU06_SecondFilterPressureDiff  AHU06_FanMaintain  AHU06_FanFault  \
# 0                               1                  0               0
# 1                               1                  0               0
# 2                               1                  0               0
# 3                               1                  0               0
# 4                               1                  0               0
#
#    AHU06_FanManualAuto  AHU06_FanOnOff  AHU06_FanOnOffDisplay  \
# 0                    0               1                      1
# 1                    0               1                      1
# ...

# %%
import seaborn as sns

# %%
correlations = temp_All_corr.corr() 
correction=abs(correlations)# 取绝对值，只看相关程度 ，不关心正相关还是负相关
# plot correlation matrix 
fig = plt.figure(figsize=(20,20)) 
ax = fig.add_subplot(figsize=(2,2)) #图片大小为20*20
ax = sns.heatmap(correction,cmap=plt.cm.Greys, linewidths=0.05,vmax=1, vmin=0 ,annot=True,annot_kws={'size':6,'weight':'bold'})
#热力图参数设置（相关系数矩阵，颜色，每个值间隔等）
#ticks = numpy.arange(0,16,1) #生成0-16，步长为1 
# plt.xticks(np.arange(16)+0.5,names) #横坐标标注点
# plt.yticks(np.arange(16)+0.5,names) #纵坐标标注点
#ax.set_xticks(ticks) #生成刻度 
#ax.set_yticks(ticks)
#ax.set_xticklabels(names) #生成x轴标签 
#ax.set_yticklabels(names)
ax.set_title('Characteristic correlation')#标题设置
# plt.savefig('cluster.jpg',dpi=300)
plt.show()
